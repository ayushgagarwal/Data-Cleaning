# %%
import pandas as pd

# %%
df = pd.read_csv("County_Health_Rankings.csv")

# %%
df
# Out:
#        State       County    State code  County code  Year span  \
# 0         US  United States         0.0          0.0  2003-2005
# 1         US  United States         0.0          0.0  2004-2006
# 2         US  United States         0.0          0.0  2005-2007
# 3         US  United States         0.0          0.0  2006-2008
# 4         US  United States         0.0          0.0  2007-2009
# ...      ...            ...         ...          ...        ...
# 303859    WY  Weston County        56.0         45.0       2007
# 303860    WY  Weston County        56.0         45.0       2008
# 303861    WY  Weston County        56.0         45.0       2009
# 303862    WY  Weston County        56.0         45.0       2010
# 303863    WY  Weston County        56.0         45.0       2011
#
#                          Measure name  Measure id    Numerator  Denominator  \
# 0                  Violent crime rate        43.0  1328750.667  274877117.0
# ...

# %% [markdown]
# # Check for unnecessary spaces in column names!

# %%
df.columns
# Out:
# Index(['State', '  County  ', 'State code', 'County code', 'Year span',
#        'Measure name', 'Measure id', 'Numerator', 'Denominator', 'Raw value',
#        'Confidence Interval Lower Bound', 'Confidence Interval Upper Bound',
#        'Data Release Year', 'fipscode'],
#       dtype='object')

# %% [markdown]
# # Replacing spaces in between with underscore and removing spaces before and after

# %%
df.columns = df.columns.str.strip().str.replace(' ', '_')
df.columns
# Out:
# Index(['State', 'County', 'State_code', 'County_code', 'Year_span',
#        'Measure_name', 'Measure_id', 'Numerator', 'Denominator', 'Raw_value',
#        'Confidence_Interval_Lower_Bound', 'Confidence_Interval_Upper_Bound',
#        'Data_Release_Year', 'fipscode'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303864 entries, 0 to 303863
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   State                            303858 non-null  object
#  1   County                           303858 non-null  object
#  2   State_code                       303860 non-null  float64
#  3   County_code                      303860 non-null  float64
#  4   Year_span                        303390 non-null  object
#  5   Measure_name                     303390 non-null  object
#  6   Measure_id                       303390 non-null  float64
#  7   Numerator                        214076 non-null  float64
#  8   Denominator                      184779 non-null  float64
#  9   Raw_value                        289956 non-null  float64
#  10  Confidence_Interval_Lower_Bound  189412 non-null  float64
# ...

# %%
df.shape
# Out:
# (303864, 14)

# %%
df.isnull().sum()
# Out:
# State                                   6
# County                                  6
# State_code                              4
# County_code                             4
# Year_span                             474
# Measure_name                          474
# Measure_id                            474
# Numerator                           89788
# Denominator                        119085
# Raw_value                           13908
# Confidence_Interval_Lower_Bound    114452
# Confidence_Interval_Upper_Bound    114452
# Data_Release_Year                  153735
# fipscode                             9581
# dtype: int64

# %% [markdown]
# # State

# %%
df.State.unique()
# Out:
# array(['US', 'AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL',
#        'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD',
#        'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM',
#        'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN',
#        'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY', 'PR', nan],
#       dtype=object)

# %% [markdown]
# # County

# %%
df.County.unique()
# Out:
# array(['United States', 'Alabama', 'Autauga County', ..., nan,
#        'Prince of Wales-Outer Ketchikan',
#        'Skagway-Hoonah-Angoon Census Ar'], dtype=object)

# %%
df.County.nunique()
# Out:
# 2008

# %%
df.describe()
# Out:
#           State_code    County_code     Measure_id     Numerator  \
# count  303860.000000  303860.000000  303390.000000  2.140760e+05
# mean       30.351807     101.981422      38.699071  1.253031e+04
# std        15.238258     107.824989      36.791425  3.516778e+05
# min         0.000000       0.000000       1.000000  0.000000e+00
# 25%        18.000000      33.000000       7.000000  2.180000e+02
# 50%        29.000000      77.000000      24.000000  8.190000e+02
# 75%        45.000000     133.000000      50.000000  2.686000e+03
# max        72.000000     840.000000     125.000000  6.214471e+07
#
#         Denominator      Raw_value  Confidence_Interval_Lower_Bound  \
# count  1.847790e+05  289956.000000                    189412.000000
# mean   1.354018e+05    1075.912013                      1348.410687
# std    3.666322e+06    2851.499091                      2902.214152
# min    1.000000e+01       0.000000                         0.000000
# ...

# %% [markdown]
# # Using min max values and below code, I know it is cleaned!

# %% [markdown]
# # State Code

# %%
for a in df["State_code"]:
    if(a%1!=0):
        print (a)
# Out:
# nan
# nan
# nan
# nan

# %% [markdown]
# # County Code

# %%
for a in df["County_code"]:
    if(a%1!=0):
        print (a)
# Out:
# nan
# nan
# nan
# nan

# %% [markdown]
# # Year Span

# %%
import numpy as np
new_df = df["Year_span"].str.split("-", n=1, expand = True).rename({0: 'Start_Year', 1: 'Finish_Year'}, axis=1).replace([None], [np.nan]).fillna(method='ffill', axis=1)
df = pd.concat((df, new_df), axis=1)

# %% [markdown]
# # Measure name

# %%
df.Measure_name.unique()
# Out:
# array(['Violent crime rate', 'Unemployment', 'Children in poverty', nan,
#        'Diabetic screening', 'Mammography screening',
#        'Preventable hospital stays', 'Uninsured',
#        'Sexually transmitted infections', 'Physical inactivity',
#        'Adult obesity', 'Premature Death',
#        'Daily fine particulate matter'], dtype=object)

# %% [markdown]
# # Consistency Check

# %%
df["test"] = df["Measure_name"] + df["Measure_id"].astype(str)
df.test.unique()
# Out:
# array(['Violent crime rate43.0', 'Unemployment23.0',
#        'Children in poverty24.0', nan, 'Diabetic screening7.0',
#        'Mammography screening50.0', 'Preventable hospital stays5.0',
#        'Uninsured85.0', 'Sexually transmitted infections45.0',
#        'Physical inactivity70.0', 'Adult obesity11.0',
#        'Premature Death1.0', 'Daily fine particulate matter125.0'],
#       dtype=object)

# %%
df.test.nunique()
# Out:
# 12

# %%
df.Measure_name.nunique()
# Out:
# 12

# %%
df.Measure_id.nunique()
# Out:
# 12

# %% [markdown]
# # numerator, denominator and raw value no idea

# %% [markdown]
# # Confidence Interval

# %%
i=0
for i in range(0,len(df["State"])):
    if(df["Confidence_Interval_Upper_Bound"][i] < df["Confidence_Interval_Lower_Bound"][i]):
        print(df["Confidence_Interval_Upper_Bound"][i],",",df["Confidence_Interval_Lower_Bound"][i] )
    i=i+1
# Out:
# 0.17464000000000002 , 15.682360000000001
# 0.18508 , 13.954920000000001
# 0.24804 , 20.052960000000002
# 0.21491999999999997 , 16.14708
# 0.20096 , 14.94904
# 0.25488 , 19.945120000000003
# 0.23784 , 18.04316
# 0.19399999999999998 , 14.450999999999999
# 0.1752 , 13.5608
# 0.17604 , 12.852960000000001
# 0.23184000000000002 , 17.44316
# 0.22491999999999998 , 17.14708
# 0.22491999999999998 , 17.14708
# 0.18216 , 14.05884
# 0.23484000000000002 , 17.74316
# 0.22588000000000003 , 17.04512
# 0.22391999999999998 , 17.047079999999998
# 0.19208 , 14.65492
# 0.20396 , 15.249039999999999
# 0.22496 , 17.34904
# 0.21191999999999997 , 15.847079999999998
# 0.23284000000000002 , 17.54316
# 0.24484 , 18.74316
# 0.19904000000000002 , 15.15296
# 0.13535999999999998 , 10.36864
# 0.26676 , 20.53924
# 0.20504 , 15.75296
# 0.21488000000000002 , 15.945120000000001
# 0.20995999999999998 , 15.849039999999999
# 0.20492 , 15.147079999999999
# 0.24884 , 19.14316
# 0.2388 , 17.9412
# 0.19996 , 14.849039999999999
# ...

# %% [markdown]
# # Lot of inconsistency within the data

# %% [markdown]
# # Data Release Year

# %%
b=[]
for a in df["Data_Release_Year"]:
    if(a%1!=0):
        b.append(a)
        print (a)
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ...

# %% [markdown]
# # County and Fipscode consistency

# %%
df["test1"] = df["County"] + df["fipscode"].astype(str)
df.test1.unique()
# Out:
# array(['United States0.0', 'Alabama1000.0', 'Autauga County1001.0', ...,
#        'Prince of Wales-Outer Ketchikan2201.0',
#        'Skagway-Hoonah-Angoon Census Ar2232.0', 'La Salle County17099.0'],
#       dtype=object)

# %%
df.test1.nunique()
# Out:
# 5202

# %%
df.fipscode.nunique()
# Out:
# 3275

# %%
df.County.nunique()
# Out:
# 2008

# %% [markdown]
# # Fipscode has many more missing values

# %%
df
# Out:
#        State         County  State_code  County_code  Year_span  \
# 0         US  United States         0.0          0.0  2003-2005
# 1         US  United States         0.0          0.0  2004-2006
# 2         US  United States         0.0          0.0  2005-2007
# 3         US  United States         0.0          0.0  2006-2008
# 4         US  United States         0.0          0.0  2007-2009
# ...      ...            ...         ...          ...        ...
# 303859    WY  Weston County        56.0         45.0       2007
# 303860    WY  Weston County        56.0         45.0       2008
# 303861    WY  Weston County        56.0         45.0       2009
# 303862    WY  Weston County        56.0         45.0       2010
# 303863    WY  Weston County        56.0         45.0       2011
#
#                          Measure_name  Measure_id    Numerator  Denominator  \
# 0                  Violent crime rate        43.0  1328750.667  274877117.0
# ...

# %%
df.isnull().sum()
# Out:
# State                                   6
# County                                  6
# State_code                              4
# County_code                             4
# Year_span                             474
# Measure_name                          474
# Measure_id                            474
# Numerator                           89788
# Denominator                        119085
# Raw_value                           13908
# Confidence_Interval_Lower_Bound    114452
# Confidence_Interval_Upper_Bound    114452
# Data_Release_Year                  153735
# fipscode                             9581
# Start_Year                            474
# Finish_Year                           474
# test                                  474
# test1                                   6
# dtype: int64

# %%
df.shape
# Out:
# (303864, 18)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# State                              0
# County                             0
# State_code                         0
# County_code                        0
# Year_span                          0
# Measure_name                       0
# Measure_id                         0
# Numerator                          0
# Denominator                        0
# Raw_value                          0
# Confidence_Interval_Lower_Bound    0
# Confidence_Interval_Upper_Bound    0
# Data_Release_Year                  0
# fipscode                           0
# Start_Year                         0
# Finish_Year                        0
# test                               0
# test1                              0
# dtype: int64

# %%
df.shape
# Out:
# (25221, 18)

# %%
df.to_csv("Cleaned.csv")
