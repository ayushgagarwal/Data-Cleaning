# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("vgsales.csv")

# %%
df.shape
# Out:
# (16598, 11)

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df.duplicated(df.columns).sum()
# Out:
# 0

# %%
def outlier(datacolumn):
    sorted(datacolumn)
    Q1,Q3 = np.percentile(datacolumn , [25,75])
    IQR = Q3 - Q1
    lower_range = Q1 - (1.5 * IQR)
    upper_range = Q3 + (1.5 * IQR)
    print (lower_range,upper_range)
    plt.hist(datacolumn)
    plt.show()

# %%
# Rank

# %%
df.Rank.nunique()
# Out:
# 16598

# %%
for a in range(len(df['Rank'])):
    df['Rank'][a]=a+1
# Out:
# c:\users\ayush agarwal\envs\test\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16594                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16595                     Men in Black II: Alien Escape       GC
# 16595  16596  SCORE International Baja 1000: The Official Game      PS2
# 16596  16597                                        Know How 2       DS
# 16597  16598                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.Rank.nunique()
# Out:
# 16598

# %%
# Name

# %%
df.Name.nunique()
# Out:
# 11493

# %%
df.Name.value_counts()
# Out:
# Need for Speed: Most Wanted             12
# FIFA 14                                  9
# Madden NFL 07                            9
# LEGO Marvel Super Heroes                 9
# Ratatouille                              9
#                                         ..
# Chou Jigen Game Neptune Mk-II            1
# Top Shot Arcade                          1
# BattleTanx                               1
# Hot Shots Golf 3                         1
# World Cup Golf: Professional Edition     1
# Name: Name, Length: 11493, dtype: int64

# %%
df[df.Name == 'FIFA 14']
# Out:
#       Rank     Name Platform    Year   Genre        Publisher  NA_Sales  \
# 112    113  FIFA 14      PS3  2013.0  Sports  Electronic Arts      0.78
# 256    257  FIFA 14     X360  2013.0  Sports  Electronic Arts      0.92
# 493    494  FIFA 14      PS4  2013.0  Sports  Electronic Arts      0.61
# 1698  1699  FIFA 14     XOne  2013.0  Sports  Electronic Arts      0.41
# 3988  3989  FIFA 14      PSV  2013.0  Sports  Electronic Arts      0.11
# 4503  4504  FIFA 14       PC  2013.0  Sports  Electronic Arts      0.01
# 4538  4539  FIFA 14      Wii  2013.0  Sports  Electronic Arts      0.00
# 6661  6662  FIFA 14      3DS  2013.0  Sports  Electronic Arts      0.00
# 7034  7035  FIFA 14      PSP  2013.0  Sports  Electronic Arts      0.00
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 112       4.32      0.07         1.73          6.90
# 256       2.93      0.01         0.46          4.31
# 493       1.85      0.11         0.33          2.90
# ...

# %%
# Platform

# %%
df.Platform.nunique()
# Out:
# 31

# %%
df.Platform.value_counts()
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# GB        98
# NES       98
# DC        52
# GEN       27
# NG        12
# WS         6
# SCD        6
# 3DO        3
# TG16       2
# PCFX       1
# GG         1
# Name: Platform, dtype: int64

# %%
# Year

# %%
df.Year.describe()
# Out:
# count    16327.000000
# mean      2006.406443
# std          5.828981
# min       1980.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2020.000000
# Name: Year, dtype: float64

# %%
df.Year.value_counts()
# Out:
# 2009.0    1431
# 2008.0    1428
# 2010.0    1259
# 2007.0    1202
# 2011.0    1139
# 2006.0    1008
# 2005.0     941
# 2002.0     829
# 2003.0     775
# 2004.0     763
# 2012.0     657
# 2015.0     614
# 2014.0     582
# 2013.0     546
# 2001.0     482
# 1998.0     379
# 2000.0     349
# 2016.0     344
# 1999.0     338
# 1997.0     289
# 1996.0     263
# 1995.0     219
# 1994.0     121
# 1993.0      60
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      36
# 1986.0      21
# 1989.0      17
# 1983.0      17
# 1990.0      16
# 1987.0      16
# 1988.0      15
# 1985.0      14
# 1984.0      14
# 1980.0       9
# 2017.0       3
# 2020.0       1
# Name: Year, dtype: int64

# %%
count=0
for a in df['Year']:
    if(a%1 != 0):
        count=count+1
count
# Out:
# 271

# %%
df.Year.isnull().sum()
# Out:
# 271

# %%
# Genre

# %%
df.Genre.nunique()
# Out:
# 12

# %%
df.Genre.value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
# Publisher

# %%
df.Publisher.nunique()
# Out:
# 578

# %%
df.Publisher.isnull().sum()
# Out:
# 58

# %%
# North American Sales

# %%
df.NA_Sales.isnull().sum()
# Out:
# 0

# %%
outlier(df['NA_Sales'])
# Out:
# -0.36 0.6

# %%
df[df['NA_Sales'] > 0.6]
# Out:
#       Rank                               Name Platform    Year         Genre  \
# 0        1                         Wii Sports      Wii  2006.0        Sports
# 1        2                  Super Mario Bros.      NES  1985.0      Platform
# 2        3                     Mario Kart Wii      Wii  2008.0        Racing
# 3        4                  Wii Sports Resort      Wii  2009.0        Sports
# 4        5           Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# ...    ...                                ...      ...     ...           ...
# 2977  2978                  NBA Street Vol. 2       XB  2003.0        Sports
# 2981  2982                 NCAA Football 2005       XB  2004.0        Sports
# 2995  2996  Cars: Mater-National Championship       DS  2007.0        Racing
# 3044  3045                 Adventures of Tron     2600  1981.0        Action
# 3079  3080                    Keystone Kapers     2600  1982.0        Action
#
# ...

# %%
df['Outlier']=0

# %%
i=0
for a in df['Outlier']:
    if(df['NA_Sales'][i] > 0.6):
        df['Outlier'][i]=1
    i=i+1
# Out:
# c:\users\ayush agarwal\envs\test\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# EU_sales

# %%
outlier(df['EU_Sales'])
# Out:
# -0.165 0.275

# %%
df[df['EU_Sales'] > 0.275]
# Out:
#       Rank                                       Name Platform    Year  \
# 0        1                                 Wii Sports      Wii  2006.0
# 1        2                          Super Mario Bros.      NES  1985.0
# 2        3                             Mario Kart Wii      Wii  2008.0
# 3        4                          Wii Sports Resort      Wii  2009.0
# 4        5                   Pokemon Red/Pokemon Blue       GB  1996.0
# ...    ...                                        ...      ...     ...
# 5463  5464                         SingStar Take That      PS3  2009.0
# 5523  5524                                    F1 2013     X360  2013.0
# 5636  5637                  Peppa Pig: Theme Park Fun       DS  2011.0
# 5643  5644  Gold's Gym: Cardio Workout (Others sales)      Wii  2008.0
# 5759  5760                      Football Manager 2016       PC  2015.0
#
#              Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
i=0
for a in df['Outlier']:
    if(df['EU_Sales'][i] > 0.275):
        df['Outlier'][i]=1
    i=i+1
# Out:
# c:\users\ayush agarwal\envs\test\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# JP Sales

# %%
outlier(df.JP_Sales)
# Out:
# -0.06 0.1

# %%
df[df['JP_Sales'] > 0.1]
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# ...      ...                                                ...      ...
# 10399  10400                  Yuusha no Kuse ni Namaikida Or 3D      PSP
# 10405  10406  Mobile Suit Gundam Age: Universe Accel / Cosmi...      PSP
# 10408  10409           Dragon Ball Z Super Gokuden: Kakusei-Hen     SNES
# 10410  10411                 Busou Shinki: Battle Masters Mk. 2      PSP
# 10412  10413                         Fairy Tail: Portable Guild      PSP
#
#          Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %%
i=0
for a in df['Outlier']:
    if(df['JP_Sales'][i] > 0.1):
        df['Outlier'][i]=1
    i=i+1
# Out:
# c:\users\ayush agarwal\envs\test\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# Other Sales

# %%
outlier(df.Other_Sales)
# Out:
# -0.06 0.1

# %%
df[df.Other_Sales > 0.1]
# Out:
#       Rank                                         Name Platform    Year  \
# 0        1                                   Wii Sports      Wii  2006.0
# 1        2                            Super Mario Bros.      NES  1985.0
# 2        3                               Mario Kart Wii      Wii  2008.0
# 3        4                            Wii Sports Resort      Wii  2009.0
# 4        5                     Pokemon Red/Pokemon Blue       GB  1996.0
# ...    ...                                          ...      ...     ...
# 7138  7139                                  TNA iMPACT!      PS2  2008.0
# 7167  7168                                    MotoGP 08      PS2  2008.0
# 7520  7521                       Buzz! The Schools Quiz      PS2  2008.0
# 8055  8056     Summer Athletics: The Ultimate Challenge      PS2  2008.0
# 9260  9261  SNK vs. Capcom: The Match of the Millennium      PS2  2006.0
#
#              Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
i=0
for a in df['Outlier']:
    if(df['Other_Sales'][i] > 0.1):
        df['Outlier'][i]=1
    i=i+1
# Out:
# c:\users\ayush agarwal\envs\test\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# Global_Sales

# %%
df[df.Global_Sales == 0]
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales, Outlier]
# Index: []

# %%
outlier(df.Global_Sales)
# Out:
# -0.5549999999999999 1.085

# %%
i=0
for a in df['Outlier']:
    if(df['Global_Sales'][i] > 1.085):
        df['Outlier'][i]=1
    i=i+1
# Out:
# c:\users\ayush agarwal\envs\test\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df.Outlier.value_counts()
# Out:
# 0    12018
# 1     4580
# Name: Outlier, dtype: int64

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16594                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16595                     Men in Black II: Alien Escape       GC
# 16595  16596  SCORE International Baja 1000: The Official Game      PS2
# 16596  16597                                        Know How 2       DS
# 16597  16598                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# You could also make different columns highlighting outliers for each column seperately.
# While creating models/analysis we could treat the outliers differently/less importance.

# %%
df.to_csv("vcleaned.csv")
